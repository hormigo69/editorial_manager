# %% [markdown]
# # Creación de la estructura de datos definitiva
# Monto un dataframe con la estructura de datos de la excel definitiva.

# %%
import pandas as pd

# import Excel Editorial Manager.xlsx and store it in a dataframe called editorial_manager_updated
editorial_manager_updated = pd.read_excel('Excel Editorial Manager.xlsx')

#check the dataframe
editorial_manager_updated.head()
# Out:
# /opt/homebrew/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:211: UserWarning: Cell P242 is marked as a date but the serial value 671072021 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# /opt/homebrew/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:211: UserWarning: Cell AQ242 is marked as a date but the serial value 671072021 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# /opt/homebrew/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Conditional Formatting extension is not supported and will be removed
#   warn(msg)
# /opt/homebrew/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#          AÑO > 10 días               REF REF MAQUETAD0  \
# 0 2022-01-01       NaN  NEFRO-D-22-00431    NEFRO-1127
# 1 2021-01-01       NaN  NEFRO-D-21-00400     NEFRO_999
# 2 2021-01-01       NaN  NEFRO-D-21-00364     NEFRO_998
# 3 2021-01-01       NaN  NEFRO-D-21-00425     NEFRO_997
# 4 2021-01-01       NaN  NEFRO-D-21-00404     NEFRO_996
#
#                                               TITULO                   ESTADO  \
# 0  PIELONEFRITIS AGUDA EN PACIENTE TRASPLANTADO R...  6. Revisión Maquetación
# 1  Renal effects of sodium-glucose co-transporter...             7. Publicado
# 2  Eficacia del ejercicio intradiálitico semi-sup...             7. Publicado
# 3  PROLAPSO DE ÓRGANOS PÉLVICOS EN MUJERES CON PO...             7. Publicado
# 4  SEPSIS POR KLUYVERA ASCORBATA EN UN PACIENTE E...             7. Publicado
#
#   Responsable                                              NOTAS    ENTRADA  \
# 0    Elsevier                                                NaN 2022-12-07
# 1    Elsevier  Es un comentario sobre la ref NEFRO-D-20-00447... 2021-07-31
# 2    Elsevier                                                NaN 2020-08-08
# 3    Elsevier                                                NaN 2021-09-15
# 4    Elsevier                                                NaN 2021-09-02
#
#   REVISIÓN  ... Etapa 1 (Entrada-Revisión) Etapa 2 (rev-coment)  \
# 0      NaT  ...                        NaN                  NaN
# 1      NaT  ...                        NaN                  NaN
# 2      NaT  ...                        NaN                  NaN
# 3      NaT  ...                        NaN                  NaN
# 4      NaT  ...                        NaN                  NaN
#
#   Etapa 3 (coment-dec) Etapa 4 (dec-entrada R1) Etapa 5 (entr R1 - Rev R1)  \
# 0                  NaN                      NaN                        NaN
# 1                  NaN                      NaN                        NaN
# 2                  NaN                      NaN                        NaN
# 3                  NaN                      NaN                        NaN
# 4                  NaN                      NaN                        NaN
#
#   Etapa 6 (acept-maqueta) Maquet-In Press Activo        Última acción  \
# 0                    14.0             NaN     ⚠️  2023-01-11 00:00:00
# 1                     NaN             NaN     ✔️  2021-12-04 00:00:00
# 2                     NaN             NaN     ✔️  2021-12-04 00:00:00
# 3                     NaN              41     ✔️  2021-12-29 00:00:00
# 4                     NaN             NaN     ✔️  2021-11-27 00:00:00
#
#   Días pasados
# 0            6
# 1          126
# 2          483
# 3          105
# 4           86
#
# [5 rows x 44 columns]

# %%
# this fucntion calculate some data from the columns obtained from Editorial Manager
import re
df = editorial_manager_updated

#extract the year from the REF column and store it in a new column called año.
# the year are the characters in NEFRO-D-21-00400 between NEFRO-D- and - adding 2000
#use a regular expression to extract the year, convert to int and add 2000
df['año'] = df['numero_manuscrito'].str.extract(r'NEFRO-D-(\d{2})-').astype(int) + 2000

#extract referencia and revision from numero_manuscrito. The REF are the first 14 characters in numero_manuscrito, the revision are the characters 17 and 18 if they exist
#use a regular expression to extract the REF and revision
df['referencia'] = df['numero_manuscrito'].str.extract(r'(.{16})')
df['revision'] = df['numero_manuscrito'].str.extract(r'(\d{2})$')

# %%
# create a dictionary to relation estado_actual from the dataframe definitiva_actual with the new ESTADO column
# the dictionary is a key value pair, the key is the value from estado_actual and the value is the new ESTADO

'''equivalencia_estados = {
    'Pendiente del Editor': '1. Nuevo esperando revisor o rechazar',
    'Pendiente del Editor R1': '1. Nuevo esperando revisor o rechazar',
    'Pendiente del Editor R2': '1. Nuevo esperando revisor o rechazar',
    'Pendiente del Editor R3': '1. Nuevo esperando revisor o rechazar',
    'Pendiente del Editor R4': '1. Nuevo esperando revisor o rechazar',
    'Pendiente evaluadores': '2. En revisión',
    'Revise / A modificar': '4.2 Grandes cambios', #check, could be 4.1 Pequeños cambios depending EM decision del editor
    'Modificaciones Enviadas': '4.2 Grandes cambios', #check, could be 4.1 Pequeños cambios depending EM decision del editor
    'Pendiente evaluadores': '2. En revisión',
    'FIN CIRCUITO: Rechazado': 'Rechazado',
    'FIN CIRCUITO: Aceptado': '5. Aceptado',
}

    '''

# %%
#remove AÑO
#df.drop('AÑO', axis=1, inplace=True)

#remove REF
#df.drop('REF', axis=1, inplace=True)

#copy the column REF to a new column called numero_manuscrito
#df['numero_manuscrito'] = df['REF']

#in the column Activo, replace the value ⚠️ by True and ✔️ by False
#df['Activo'] = df['Activo'].replace({'⚠️': True, '✔️': False})

#in the column > 10 días, add True if Activo is True and Dïas pasado is greater than 10. else add False
#df['> 10 días'] = df['Activo'] & (df['Días pasados'] > 10)

#add the columns that we have in the dataframe definitiva_actual but not in the dataframe editorial_manager_updated
#definitiva_actual columns: 'numero_manuscrito', 'tipo_articulo', 'titulo', 'autor', 
# 'fecha_inicial', 'fecha_estado', 'estado_actual', 'editor',
# 'estado_evaluacion', 'decision_editor', 'data_identity',
# 'est_ev_completo', 'est_ev_aceptado', 'est_ev_invitado',
# 'est_ev_rechazado', 'est_ev_tarde', 'email', 'fecha_vencimiento',
# 'fecha_alta', 'fecha_baja'],

#add 'tipo_articulo', 'autor', 'fecha_inicial', 'data_identity','est_ev_completo', 'est_ev_aceptado', 'est_ev_invitado',
# 'est_ev_rechazado', 'est_ev_tarde', 'email', 'fecha_vencimiento', 'fecha_alta', 'fecha_baja'
df['tipo_articulo'] = ''
df['autor'] = ''
df['fecha_inicial'] = ''
df['data_identity'] = ''
df['est_ev_completo'] = ''
df['est_ev_aceptado'] = ''
df['est_ev_invitado'] = ''
df['est_ev_rechazado'] = ''
df['est_ev_tarde'] = ''
df['email'] = ''
df['fecha_vencimiento'] = ''
df['fecha_alta'] = ''
df['fecha_baja'] = ''


#rename all the columns to avois caps
df.columns = df.columns.str.lower()

# %%
df['decision_editor'] =''

# %%
#rename estado actual to estado_actual
df.rename(columns={'fecha _estado': 'fecha_estado'}, inplace=True)

# %%
#rename ref maquetad0 to ref_maquetado
df.rename(columns={'ref maquetad0': 'ref_maquetado'}, inplace=True)
# rename revisión to revision
df.rename(columns={'revisión': 'revision_1'}, inplace=True)
#rename coment compl del último revisor to comentarios_ultimo_revisor
df.rename(columns={'coment compl del último revisor': 'comentarios_ultimo_revisor'}, inplace=True)
#rename dec editor para autor to decision_editor
df.rename(columns={'dec editor para autor': 'decision_editor'}, inplace=True)

# %%
df.columns
# Out:
# Index(['> 10 días', 'ref_maquetado', 'titulo', 'estado', 'responsable',
#        'notas', 'entrada', 'revision_1', 'comentarios_ultimo_revisor',
#        'decision_editor', 'entrada r1 (para director: nuevo artículo)',
#        'revisión r1 (primera invitación para revisor: invitación)',
#        'coment compl r1 (el último que llegue)',
#        'dec editor (el siguiente para autor:)',
#        'entrada r2 (el siguiente para director: nuevo artículo)',
#        'revisión r2 (el siguiente para revisor: invitación)',
#        'coment compl r2', 'dec editor', 'entrada r3', 'revisión r3',
#        'coment compl r3', 'dec editor2', 'entrada r4', 'revisión r4',
#        'coment compl r4', 'rechazo', 'aceptación', 'maquetación', 'in press',
#        'publicado', 'publicado - detalles', 'pmid',
#        'etapa 1 (entrada-revisión)', 'etapa 2 (rev-coment)',
#        'etapa 3 (coment-dec)', 'etapa 4 (dec-entrada r1)',
#        'etapa 5 (entr r1 - rev r1)', 'etapa 6 (acept-maqueta)',
#        'maquet-in press', 'activo', 'última acción', 'días pasados', 'año',
#        'numero_manuscrito', 'referencia', 'revision', 'tipo_articulo', 'autor',
#        'fecha_inicial', 'data_identity', 'est_ev_completo', 'est_ev_aceptado',
#        'est_ev_invitado', 'est_ev_rechazado', 'est_ev_tarde', 'email',
#        'fecha_vencimiento', 'fecha_alta', 'fecha_baja', 'estado_actual',
#        'fecha_estado', 'editor'],
#       dtype='object')

# %%
#reorder the columns to this order:
# data_identity, numero_manuscrito, referencia, revision, titulo, tipo_articulo, autor, email, fecha_inicial, estado actual,
# fecha_estado, fecha vencimiento, editor, decision_editor, est_ev_completo, est_ev_aceptado, est_ev_invitado, est_ev_tarde,
#
# año, referencia_maquetado, estado, responsable, notas, 'entrada', 'revision_1', 'comentarios_ultimo_revisor',
# 'decision_editor', 'entrada r1 (para director: nuevo artículo)', 'revisión r1 (primera invitación para revisor: invitación)',
# 'coment compl r1 (el último que llegue)', 'dec editor (el siguiente para autor:)', 'entrada r2 (el siguiente para director: nuevo artículo)',
# 'revisión r2 (el siguiente para revisor: invitación)', 'coment compl r2', 'dec editor', 'entrada r3', 'revisión r3',
# 'coment compl r3', 'dec editor2', 'entrada r4', 'revisión r4', 'coment compl r4', 'rechazo', 'aceptación', 'maquetación',
#  'in press', 'publicado', 'publicado - detalles', 'pmid','etapa 1 (entrada-revisión)', 'etapa 2 (rev-coment)',
# 'etapa 3 (coment-dec)', 'etapa 4 (dec-entrada r1)', 'etapa 5 (entr r1 - rev r1)', 'etapa 6 (acept-maqueta)',
# 'maquet-in press', 'activo', 'última acción', 'días pasados', > 10 días

df = df[[
'data_identity', 'numero_manuscrito', 'referencia', 'revision', 'titulo', 'tipo_articulo', 'autor', 'email', 'fecha_inicial', 'estado_actual',
'fecha_estado', 'fecha_vencimiento', 'editor', 'decision_editor', 'est_ev_completo', 'est_ev_aceptado', 'est_ev_invitado', 'est_ev_tarde',
'año', 'ref_maquetado', 'estado', 'responsable', 'notas', 'entrada', 'revision_1', 'comentarios_ultimo_revisor',
'decision_editor', 'entrada r1 (para director: nuevo artículo)', 'revisión r1 (primera invitación para revisor: invitación)',
'coment compl r1 (el último que llegue)', 'dec editor (el siguiente para autor:)', 'entrada r2 (el siguiente para director: nuevo artículo)',
'revisión r2 (el siguiente para revisor: invitación)', 'coment compl r2', 'dec editor', 'entrada r3', 'revisión r3',
'coment compl r3', 'dec editor2', 'entrada r4', 'revisión r4', 'coment compl r4', 'rechazo', 'aceptación', 'maquetación',
'in press', 'publicado', 'publicado - detalles', 'pmid','etapa 1 (entrada-revisión)', 'etapa 2 (rev-coment)',
'etapa 3 (coment-dec)', 'etapa 4 (dec-entrada r1)', 'etapa 5 (entr r1 - rev r1)', 'etapa 6 (acept-maqueta)',
'maquet-in press', 'activo', 'última acción', 'días pasados', '> 10 días']]

# %%
#rename:        'entrada r1 (para director: nuevo artículo)'  to 'entrada_r1'
df.rename(columns={'entrada r1 (para director: nuevo artículo)': 'entrada_r1'}, inplace=True)
#rename:        'revisión r1 (primera invitación para revisor: invitación)'  to 'revision_r1'
df.rename(columns={'revisión r1 (primera invitación para revisor: invitación)': 'revision_r1'}, inplace=True)
#rename:        'coment compl r1 (el último que llegue)'  to 'comentarios_r1'
df.rename(columns={'coment compl r1 (el último que llegue)': 'comentarios_completos_r1'}, inplace=True)
#rename:        'dec editor (el siguiente para autor:)'  to 'decision_editor_r1'
df.rename(columns={'dec editor (el siguiente para autor:)': 'decision_editor_r1'}, inplace=True)
#rename:        'entrada r2 (el siguiente para director: nuevo artículo)'  to 'entrada_r2'
df.rename(columns={'entrada r2 (el siguiente para director: nuevo artículo)': 'entrada_r2'}, inplace=True)
#rename:        'revisión r2 (el siguiente para revisor: invitación)'  to 'revision_r2'
df.rename(columns={'revisión r2 (el siguiente para revisor: invitación)': 'revision_r2'}, inplace=True)
#rename:        'coment compl r2'  to 'comentarios_completos_r2'
df.rename(columns={'coment compl r2': 'comentarios_completos_r2'}, inplace=True)
#rename:        'dec editor'  to 'decision_editor_r2'
df.rename(columns={'dec editor': 'decision_editor_r2'}, inplace=True)
#rename:        'entrada r3'  to 'entrada_r3'
df.rename(columns={'entrada r3': 'entrada_r3'}, inplace=True)
#rename:        'revisión r3'  to 'revision_r3'
df.rename(columns={'revisión r3': 'revision_r3'}, inplace=True)
#rename:        'coment compl r3'  to 'comentarios_completos_r3'
df.rename(columns={'coment compl r3': 'comentarios_completos_r3'}, inplace=True)
#rename:        'dec editor2'  to 'decision_editor_r3'
df.rename(columns={'dec editor2': 'decision_editor_r3'}, inplace=True)
#rename:        'entrada r4'  to 'entrada_r4'
df.rename(columns={'entrada r4': 'entrada_r4'}, inplace=True)
#rename:        'revisión r4'  to 'revision_r4'
df.rename(columns={'revisión r4': 'revision_r4'}, inplace=True)
#rename:        'coment compl r4'  to 'comentarios_completos_r4'
df.rename(columns={'coment compl r4': 'comentarios_completos_r4'}, inplace=True)
# rename publicado - detalles to publicado_detalles
df.rename(columns={'publicado - detalles': 'publicado_detalles'}, inplace=True)
# rename etapa 1 (entrada-revisión) to etapa_1
df.rename(columns={'etapa 1 (entrada-revisión)': 'etapa_1'}, inplace=True)
# rename etapa 2 (rev-coment) to etapa_2
df.rename(columns={'etapa 2 (rev-coment)': 'etapa_2'}, inplace=True)
# rename etapa 3 (coment-dec) to etapa_3
df.rename(columns={'etapa 3 (coment-dec)': 'etapa_3'}, inplace=True)
# rename etapa 4 (dec-entrada r1) to etapa_4
df.rename(columns={'etapa 4 (dec-entrada r1)': 'etapa_4'}, inplace=True)
# rename etapa 5 (entr r1 - rev r1) to etapa_5
df.rename(columns={'etapa 5 (entr r1 - rev r1)': 'etapa_5'}, inplace=True)
# rename etapa 6 (acept-maqueta) to etapa_6
df.rename(columns={'etapa 6 (acept-maqueta)': 'etapa_6'}, inplace=True)
# rename maquet-in press to maquet_in_press
df.rename(columns={'maquet-in press': 'maquet_in_press'}, inplace=True)
# rename último acción to ultima_accion
df.rename(columns={'última acción': 'ultima_accion'}, inplace=True)
# rename días pasados to dias_pasados
df.rename(columns={'días pasados': 'dias_pasados'}, inplace=True)
# rename > 10 días to mas_de_10_dias
df.rename(columns={'> 10 días': 'mas_de_10_dias'}, inplace=True)
# Out:
# /var/folders/ch/63kj7hh97f1_0yrh4d1t0t8c0000gn/T/ipykernel_51671/3400815365.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'entrada r1 (para director: nuevo artículo)': 'entrada_r1'}, inplace=True)
# /var/folders/ch/63kj7hh97f1_0yrh4d1t0t8c0000gn/T/ipykernel_51671/3400815365.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'revisión r1 (primera invitación para revisor: invitación)': 'revision_r1'}, inplace=True)
# /var/folders/ch/63kj7hh97f1_0yrh4d1t0t8c0000gn/T/ipykernel_51671/3400815365.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'coment compl r1 (el último que llegue)': 'comentarios_completos_r1'}, inplace=True)
# /var/folders/ch/63kj7hh97f1_0yrh4d1t0t8c0000gn/T/ipykernel_51671/3400815365.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'dec editor (el siguiente para autor:)': 'decision_editor_r1'}, inplace=True)
# /var/folders/ch/63kj7hh97f1_0yrh4d1t0t8c0000gn/T/ipykernel_51671/3400815365.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'entrada r2 (el siguiente para director: nuevo artículo)': 'entrada_r2'}, inplace=True)
# /var/folders/ch/63kj7hh97f1_0yrh4d1t0t8c0000gn/T/ipykernel_51671/3400815365.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'revisión r2 (el siguiente para revisor: invitación)': 'revision_r2'}, inplace=True)
# /var/folders/ch/63kj7hh97f1_0yrh4d1t0t8c0000gn/T/ipykernel_51671/3400815365.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'coment compl r2': 'comentarios_completos_r2'}, inplace=True)
# /var/folders/ch/63kj7hh97f1_0yrh4d1t0t8c0000gn/T/ipykernel_51671/3400815365.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'dec editor': 'decision_editor_r2'}, inplace=True)
# /var/folders/ch/63kj7hh97f1_0yrh4d1t0t8c0000gn/T/ipykernel_51671/3400815365.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'entrada r3': 'entrada_r3'}, inplace=True)
# /var/folders/ch/63kj7hh97f1_0yrh4d1t0t8c0000gn/T/ipykernel_51671/3400815365.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'revisión r3': 'revision_r3'}, inplace=True)
# /var/folders/ch/63kj7hh97f1_0yrh4d1t0t8c0000gn/T/ipykernel_51671/3400815365.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'coment compl r3': 'comentarios_completos_r3'}, inplace=True)
# /var/folders/ch/63kj7hh97f1_0yrh4d1t0t8c0000gn/T/ipykernel_51671/3400815365.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'dec editor2': 'decision_editor_r3'}, inplace=True)
# /var/folders/ch/63kj7hh97f1_0yrh4d1t0t8c0000gn/T/ipykernel_51671/3400815365.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'entrada r4': 'entrada_r4'}, inplace=True)
# /var/folders/ch/63kj7hh97f1_0yrh4d1t0t8c0000gn/T/ipykernel_51671/3400815365.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'revisión r4': 'revision_r4'}, inplace=True)
# /var/folders/ch/63kj7hh97f1_0yrh4d1t0t8c0000gn/T/ipykernel_51671/3400815365.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'coment compl r4': 'comentarios_completos_r4'}, inplace=True)
# /var/folders/ch/63kj7hh97f1_0yrh4d1t0t8c0000gn/T/ipykernel_51671/3400815365.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'publicado - detalles': 'publicado_detalles'}, inplace=True)
# /var/folders/ch/63kj7hh97f1_0yrh4d1t0t8c0000gn/T/ipykernel_51671/3400815365.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'etapa 1 (entrada-revisión)': 'etapa_1'}, inplace=True)
# /var/folders/ch/63kj7hh97f1_0yrh4d1t0t8c0000gn/T/ipykernel_51671/3400815365.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'etapa 2 (rev-coment)': 'etapa_2'}, inplace=True)
# /var/folders/ch/63kj7hh97f1_0yrh4d1t0t8c0000gn/T/ipykernel_51671/3400815365.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'etapa 3 (coment-dec)': 'etapa_3'}, inplace=True)
# /var/folders/ch/63kj7hh97f1_0yrh4d1t0t8c0000gn/T/ipykernel_51671/3400815365.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'etapa 4 (dec-entrada r1)': 'etapa_4'}, inplace=True)
# /var/folders/ch/63kj7hh97f1_0yrh4d1t0t8c0000gn/T/ipykernel_51671/3400815365.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'etapa 5 (entr r1 - rev r1)': 'etapa_5'}, inplace=True)
# /var/folders/ch/63kj7hh97f1_0yrh4d1t0t8c0000gn/T/ipykernel_51671/3400815365.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'etapa 6 (acept-maqueta)': 'etapa_6'}, inplace=True)
# /var/folders/ch/63kj7hh97f1_0yrh4d1t0t8c0000gn/T/ipykernel_51671/3400815365.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'maquet-in press': 'maquet_in_press'}, inplace=True)
# /var/folders/ch/63kj7hh97f1_0yrh4d1t0t8c0000gn/T/ipykernel_51671/3400815365.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'última acción': 'ultima_accion'}, inplace=True)
# /var/folders/ch/63kj7hh97f1_0yrh4d1t0t8c0000gn/T/ipykernel_51671/3400815365.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'días pasados': 'dias_pasados'}, inplace=True)
# /var/folders/ch/63kj7hh97f1_0yrh4d1t0t8c0000gn/T/ipykernel_51671/3400815365.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'> 10 días': 'mas_de_10_dias'}, inplace=True)

# %%
df.columns
# Out:
# Index(['data_identity', 'numero_manuscrito', 'referencia', 'revision',
#        'titulo', 'tipo_articulo', 'autor', 'email', 'fecha_inicial',
#        'estado_actual', 'fecha_estado', 'fecha_vencimiento', 'editor',
#        'decision_editor', 'est_ev_completo', 'est_ev_aceptado',
#        'est_ev_invitado', 'est_ev_tarde', 'año', 'ref_maquetado', 'estado',
#        'responsable', 'notas', 'entrada', 'revision_1',
#        'comentarios_ultimo_revisor', 'decision_editor', 'entrada_r1',
#        'revision_r1', 'comentarios_completos_r1', 'decision_editor_r1',
#        'entrada_r2', 'revision_r2', 'comentarios_completos_r2',
#        'decision_editor_r2', 'entrada_r3', 'revision_r3',
#        'comentarios_completos_r3', 'decision_editor_r3', 'entrada_r4',
#        'revision_r4', 'comentarios_completos_r4', 'rechazo', 'aceptación',
#        'maquetación', 'in press', 'publicado', 'publicado_detalles', 'pmid',
#        'etapa_1', 'etapa_2', 'etapa_3', 'etapa_4', 'etapa_5', 'etapa_6',
#        'maquet_in_press', 'activo', 'ultima_accion', 'dias_pasados',
#        'mas_de_10_dias'],
#       dtype='object')

# %%
df.head()
# Out:
#   data_identity numero_manuscrito        referencia revision  \
# 0                NEFRO-D-22-00431  NEFRO-D-22-00431       31
# 1                NEFRO-D-21-00400  NEFRO-D-21-00400       00
# 2                NEFRO-D-21-00364  NEFRO-D-21-00364       64
# 3                NEFRO-D-21-00425  NEFRO-D-21-00425       25
# 4                NEFRO-D-21-00404  NEFRO-D-21-00404       04
#
#                                               titulo tipo_articulo autor  \
# 0  PIELONEFRITIS AGUDA EN PACIENTE TRASPLANTADO R...
# 1  Renal effects of sodium-glucose co-transporter...
# 2  Eficacia del ejercicio intradiálitico semi-sup...
# 3  PROLAPSO DE ÓRGANOS PÉLVICOS EN MUJERES CON PO...
# 4  SEPSIS POR KLUYVERA ASCORBATA EN UN PACIENTE E...
#
#   email fecha_inicial estado_actual  ... etapa_2 etapa_3 etapa_4 etapa_5  \
# 0                                    ...     NaN     NaN     NaN     NaN
# 1                                    ...     NaN     NaN     NaN     NaN
# 2                                    ...     NaN     NaN     NaN     NaN
# 3                                    ...     NaN     NaN     NaN     NaN
# 4                                    ...     NaN     NaN     NaN     NaN
#
#   etapa_6 maquet_in_press activo        ultima_accion  dias_pasados  \
# 0    14.0             NaN   True  2023-01-11 00:00:00             6
# 1     NaN             NaN  False  2021-12-04 00:00:00           126
# 2     NaN             NaN  False  2021-12-04 00:00:00           483
# 3     NaN              41  False  2021-12-29 00:00:00           105
# 4     NaN             NaN  False  2021-11-27 00:00:00            86
#
#   mas_de_10_dias
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#
# [5 rows x 60 columns]

# %%
#export to csv
df.to_csv('db_editorial_manager.csv', index=False)

# %%
editorial_manager_updated.head()
# Out:
#    > 10 días ref_maquetado                                             titulo  \
# 0      False    NEFRO-1127  PIELONEFRITIS AGUDA EN PACIENTE TRASPLANTADO R...
# 1      False     NEFRO_999  Renal effects of sodium-glucose co-transporter...
# 2      False     NEFRO_998  Eficacia del ejercicio intradiálitico semi-sup...
# 3      False     NEFRO_997  PROLAPSO DE ÓRGANOS PÉLVICOS EN MUJERES CON PO...
# 4      False     NEFRO_996  SEPSIS POR KLUYVERA ASCORBATA EN UN PACIENTE E...
#
#                     estado responsable  \
# 0  6. Revisión Maquetación    Elsevier
# 1             7. Publicado    Elsevier
# 2             7. Publicado    Elsevier
# 3             7. Publicado    Elsevier
# 4             7. Publicado    Elsevier
#
#                                                notas    entrada revision_1  \
# 0                                                NaN 2022-12-07        NaT
# 1  Es un comentario sobre la ref NEFRO-D-20-00447... 2021-07-31        NaT
# 2                                                NaN 2020-08-08        NaT
# 3                                                NaN 2021-09-15        NaT
# 4                                                NaN 2021-09-02        NaT
#
#   comentarios_ultimo_revisor decision_editor  ... est_ev_invitado  \
# 0                        NaT                  ...
# 1                        NaT                  ...
# 2                        NaT                  ...
# 3                        NaT                  ...
# 4                        NaT                  ...
#
#   est_ev_rechazado est_ev_tarde email fecha_vencimiento fecha_alta fecha_baja  \
# 0
# 1
# 2
# 3
# 4
#
#   estado_actual fecha_estado editor
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 62 columns]

# %%
#move the data from editorial_manager_updated to df column by column
#'> 10 días', 'ref_maquetado', 'titulo', 'estado', 'responsable',
#       'notas', 'entrada', 'revision_1', 'comentarios_ultimo_revisor',
 #      'decision_editor', 'entrada r1 (para director: nuevo artículo)',
 #      'revisión r1 (primera invitación para revisor: invitación)',
 #      'coment compl r1 (el último que llegue)',
 #      'dec editor (el siguiente para autor:)',
 #      'revisión r2 (el siguiente para revisor: invitación)',
 #      'entrada r2 (el siguiente para director: nuevo artículo)',
 #      'coment compl r3', 'dec editor2', 'entrada r4', 'revisión r4',
 #      'coment compl r2', 'dec editor', 'entrada r3', 'revisión r3',
 #      'coment compl r4', 'rechazo', 'aceptación', 'maquetación', 'in press',
   #    'etapa 1 (entrada-revisión)', 'etapa 2 (rev-coment)',
  #     'publicado', 'publicado - detalles', 'pmid',
 #      'etapa 3 (coment-dec)', 'etapa 4 (dec-entrada r1)',
  #     'etapa 5 (entr r1 - rev r1)', 'etapa 6 (acept-maqueta)',
#       'maquet-in press', 'activo', 'última acción', 'días pasados', 'año',
#       'numero_manuscrito', 'referencia', 'revision', 'tipo_articulo', 'autor',
#       'fecha_inicial', 'data_identity', 'est_ev_completo', 'est_ev_aceptado',
#       'est_ev_invitado', 'est_ev_rechazado', 'est_ev_tarde', 'email',
#       'fecha_vencimiento', 'fecha_alta', 'fecha_baja', 'estado_actual',
#       'fecha_estado', 'editor'],


df['ref_maquetado'] = editorial_manager_updated['ref_maquetado']
df['titulo'] = editorial_manager_updated['titulo']
df['estado'] = editorial_manager_updated['estado']
df['responsable'] = editorial_manager_updated['responsable']
df['notas'] = editorial_manager_updated['notas']
df['entrada'] = editorial_manager_updated['entrada']
df['revision_1'] = editorial_manager_updated['revision_1']
df['comentarios_ultimo_revisor'] = editorial_manager_updated['comentarios_ultimo_revisor']
df['decision_editor'] = editorial_manager_updated['decision_editor']
df['entrada_r1'] = editorial_manager_updated['entrada r1 (para director: nuevo artículo)']
df['revision_r1'] = editorial_manager_updated['revisión r1 (primera invitación para revisor: invitación)']
df['comentarios_completos_r1'] = editorial_manager_updated['coment compl r1 (el último que llegue)']
df['decision_editor_r1'] = editorial_manager_updated['dec editor (el siguiente para autor:)']
df['entrada_r2'] = editorial_manager_updated['entrada r2 (el siguiente para director: nuevo artículo)']
df['revision_r2'] = editorial_manager_updated['revisión r2 (el siguiente para revisor: invitación)']
df['comentarios_completos_r2'] = editorial_manager_updated['coment compl r2']
df['decision_editor_r2'] = editorial_manager_updated['dec editor']
df['entrada_r3'] = editorial_manager_updated['entrada r3']
df['revision_r3'] = editorial_manager_updated['revisión r3']
df['comentarios_completos_r3'] = editorial_manager_updated['coment compl r3']
df['decision_editor_r3'] = editorial_manager_updated['dec editor2']
df['entrada_r4'] = editorial_manager_updated['entrada r4']
df['revision_r4'] = editorial_manager_updated['revisión r4']
df['comentarios_completos_r4'] = editorial_manager_updated['coment compl r4']
df['rechazo'] = editorial_manager_updated['rechazo']
df['aceptacion'] = editorial_manager_updated['aceptación']
df['maquetacion'] = editorial_manager_updated['maquetación']
df['in_press'] = editorial_manager_updated['in press']
df['publicado'] = editorial_manager_updated['publicado']
df['publicado_detalles'] = editorial_manager_updated['publicado - detalles']
df['pmid'] = editorial_manager_updated['pmid']
df['etapa_1'] = editorial_manager_updated['etapa 1 (entrada-revisión)']
df['etapa_2'] = editorial_manager_updated['etapa 2 (rev-coment)']
df['etapa_3'] = editorial_manager_updated['etapa 3 (coment-dec)']
df['etapa_4'] = editorial_manager_updated['etapa 4 (dec-entrada r1)']
df['etapa_5'] = editorial_manager_updated['etapa 5 (entr r1 - rev r1)']
df['etapa_6'] = editorial_manager_updated['etapa 6 (acept-maqueta)']
df['maquet_in_press'] = editorial_manager_updated['maquet-in press']
df['activo'] = editorial_manager_updated['activo']
df['ultima_accion'] = editorial_manager_updated['última acción']
df['dias_pasados'] = editorial_manager_updated['días pasados']
# Out:
# /var/folders/ch/63kj7hh97f1_0yrh4d1t0t8c0000gn/T/ipykernel_51671/1785047635.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ref_maquetado'] = editorial_manager_updated['ref_maquetado']
# /var/folders/ch/63kj7hh97f1_0yrh4d1t0t8c0000gn/T/ipykernel_51671/1785047635.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['titulo'] = editorial_manager_updated['titulo']
# /var/folders/ch/63kj7hh97f1_0yrh4d1t0t8c0000gn/T/ipykernel_51671/1785047635.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['estado'] = editorial_manager_updated['estado']
# /var/folders/ch/63kj7hh97f1_0yrh4d1t0t8c0000gn/T/ipykernel_51671/1785047635.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['responsable'] = editorial_manager_updated['responsable']
# /var/folders/ch/63kj7hh97f1_0yrh4d1t0t8c0000gn/T/ipykernel_51671/1785047635.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['notas'] = editorial_manager_updated['notas']
# /var/folders/ch/63kj7hh97f1_0yrh4d1t0t8c0000gn/T/ipykernel_51671/1785047635.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['entrada'] = editorial_manager_updated['entrada']
# /var/folders/ch/63kj7hh97f1_0yrh4d1t0t8c0000gn/T/ipykernel_51671/1785047635.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['revision_1'] = editorial_manager_updated['revision_1']
# /var/folders/ch/63kj7hh97f1_0yrh4d1t0t8c0000gn/T/ipykernel_51671/1785047635.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['comentarios_ultimo_revisor'] = editorial_manager_updated['comentarios_ultimo_revisor']
# /var/folders/ch/63kj7hh97f1_0yrh4d1t0t8c0000gn/T/ipykernel_51671/1785047635.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['decision_editor'] = editorial_manager_updated['decision_editor']
# /var/folders/ch/63kj7hh97f1_0yrh4d1t0t8c0000gn/T/ipykernel_51671/1785047635.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['entrada_r1'] = editorial_manager_updated['entrada r1 (para director: nuevo artículo)']
# /var/folders/ch/63kj7hh97f1_0yrh4d1t0t8c0000gn/T/ipykernel_51671/1785047635.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['revision_r1'] = editorial_manager_updated['revisión r1 (primera invitación para revisor: invitación)']
# /var/folders/ch/63kj7hh97f1_0yrh4d1t0t8c0000gn/T/ipykernel_51671/1785047635.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['comentarios_completos_r1'] = editorial_manager_updated['coment compl r1 (el último que llegue)']
# /var/folders/ch/63kj7hh97f1_0yrh4d1t0t8c0000gn/T/ipykernel_51671/1785047635.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['decision_editor_r1'] = editorial_manager_updated['dec editor (el siguiente para autor:)']
# /var/folders/ch/63kj7hh97f1_0yrh4d1t0t8c0000gn/T/ipykernel_51671/1785047635.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['entrada_r2'] = editorial_manager_updated['entrada r2 (el siguiente para director: nuevo artículo)']
# /var/folders/ch/63kj7hh97f1_0yrh4d1t0t8c0000gn/T/ipykernel_51671/1785047635.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['revision_r2'] = editorial_manager_updated['revisión r2 (el siguiente para revisor: invitación)']
# /var/folders/ch/63kj7hh97f1_0yrh4d1t0t8c0000gn/T/ipykernel_51671/1785047635.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['comentarios_completos_r2'] = editorial_manager_updated['coment compl r2']
# /var/folders/ch/63kj7hh97f1_0yrh4d1t0t8c0000gn/T/ipykernel_51671/1785047635.py:41: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['decision_editor_r2'] = editorial_manager_updated['dec editor']
# /var/folders/ch/63kj7hh97f1_0yrh4d1t0t8c0000gn/T/ipykernel_51671/1785047635.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['entrada_r3'] = editorial_manager_updated['entrada r3']
# /var/folders/ch/63kj7hh97f1_0yrh4d1t0t8c0000gn/T/ipykernel_51671/1785047635.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['revision_r3'] = editorial_manager_updated['revisión r3']
# /var/folders/ch/63kj7hh97f1_0yrh4d1t0t8c0000gn/T/ipykernel_51671/1785047635.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['comentarios_completos_r3'] = editorial_manager_updated['coment compl r3']
# /var/folders/ch/63kj7hh97f1_0yrh4d1t0t8c0000gn/T/ipykernel_51671/1785047635.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['decision_editor_r3'] = editorial_manager_updated['dec editor2']
# /var/folders/ch/63kj7hh97f1_0yrh4d1t0t8c0000gn/T/ipykernel_51671/1785047635.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['entrada_r4'] = editorial_manager_updated['entrada r4']
# /var/folders/ch/63kj7hh97f1_0yrh4d1t0t8c0000gn/T/ipykernel_51671/1785047635.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['revision_r4'] = editorial_manager_updated['revisión r4']
# /var/folders/ch/63kj7hh97f1_0yrh4d1t0t8c0000gn/T/ipykernel_51671/1785047635.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['comentarios_completos_r4'] = editorial_manager_updated['coment compl r4']
# /var/folders/ch/63kj7hh97f1_0yrh4d1t0t8c0000gn/T/ipykernel_51671/1785047635.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['rechazo'] = editorial_manager_updated['rechazo']
# /var/folders/ch/63kj7hh97f1_0yrh4d1t0t8c0000gn/T/ipykernel_51671/1785047635.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['aceptacion'] = editorial_manager_updated['aceptación']

# %%
#df.loc[406,'aceptacion'] = ''

#find ref_maquetado = NEFRO_991
#df[df['ref_maquetado'] == 'NEFRO_877']

#print the content of the column aceptacion if is not NaN ordered by the column 'aceptacion'
#df[df['aceptacion'].notna()].sort_values(by=['aceptacion'])

# print the content of aceptacion from the row 955
#df.loc[112,'in_press']
#change '17/1172021' to '17/11/2021'
df.loc[112,'in_press'] = '2021-6-18 00:00:00'

# %%
#convert all the dates to dd/mm/yyyy format
#df['entrada'] = pd.to_datetime(df['entrada']).dt.strftime('%d/%m/%Y')
#df['revision_1'] = pd.to_datetime(df['revision_1']).dt.strftime('%d/%m/%Y')
#df['comentarios_ultimo_revisor'] = pd.to_datetime(df['comentarios_ultimo_revisor']).dt.strftime('%d/%m/%Y')

#df['decision_editor'] = pd.to_datetime(df['decision_editor']).dt.strftime('%d/%m/%Y')

#df['entrada_r1'] = pd.to_datetime(df['entrada_r1']).dt.strftime('%d/%m/%Y')
#df['comentarios_completos_r1'] = pd.to_datetime(df['comentarios_completos_r1']).dt.strftime('%d/%m/%Y')
#df['revision_r1'] = pd.to_datetime(df['revision_r1']).dt.strftime('%d/%m/%Y')
#df['decision_editor_r1'] = pd.to_datetime(df['decision_editor_r1']).dt.strftime('%d/%m/%Y')
#df['entrada_r2'] = pd.to_datetime(df['entrada_r2']).dt.strftime('%d/%m/%Y')
#df['revision_r2'] = pd.to_datetime(df['revision_r2']).dt.strftime('%d/%m/%Y')
#df['comentarios_completos_r2'] = pd.to_datetime(df['comentarios_completos_r2']).dt.strftime('%d/%m/%Y')
#df['decision_editor_r2'] = pd.to_datetime(df['decision_editor_r2']).dt.strftime('%d/%m/%Y')
#df['entrada_r3'] = pd.to_datetime(df['entrada_r3']).dt.strftime('%d/%m/%Y')
#df['revision_r3'] = pd.to_datetime(df['revision_r3']).dt.strftime('%d/%m/%Y')
#df['comentarios_completos_r3'] = pd.to_datetime(df['comentarios_completos_r3']).dt.strftime('%d/%m/%Y')
#df['entrada_r4'] = pd.to_datetime(df['entrada_r4']).dt.strftime('%d/%m/%Y')
#df['decision_editor_r3'] = pd.to_datetime(df['decision_editor_r3']).dt.strftime('%d/%m/%Y')
#df['revision_r4'] = pd.to_datetime(df['revision_r4']).dt.strftime('%d/%m/%Y')
#df['comentarios_completos_r4'] = pd.to_datetime(df['comentarios_completos_r4']).dt.strftime('%d/%m/%Y')
#df['rechazo'] = pd.to_datetime(df['rechazo']).dt.strftime('%d/%m/%Y')

#df['aceptacion'] = pd.to_datetime(df['aceptacion']).dt.strftime('%d/%m/%Y')

###df['maquetacion'] = pd.to_datetime(df['maquetacion']).dt.strftime('%d/%m/%Y')

df['in_press'] = pd.to_datetime(df['in_press']).dt.strftime('%d/%m/%Y')

#df['publicado'] = pd.to_datetime(df['publicado']).dt.strftime('%d/%m/%Y')

#df['ultima_accion'] = pd.to_datetime(df['ultima_accion']).dt.strftime('%d/%m/%Y')

# %%
#export to excel
df.to_excel('editorial_manager_updated.xlsx', index=False)

#export to csv
df.to_csv('editorial_manager_updated.csv', index=False)

# %% [markdown]
# # Empiezo desde cero. Ya sé lo que quiero pero veo errores en la importación de algunas fechas.

# %%
#create a new empty df from the scratch with the columns that I want

final_columns = ['data_identity', 'numero_manuscrito', 'referencia', 'revision',
       'titulo', 'tipo_articulo', 'autor', 'email', 'fecha_inicial',
       'estado_actual', 'fecha_estado', 'fecha_vencimiento', 'editor', 'decision_editor',
       'est_ev_completo', 'est_ev_aceptado', 'est_ev_invitado', 'est_ev_rechazado', 'est_ev_tarde',
       'año', 'ref_maquetado', 'estado', 'responsable', 'notas', 'entrada',
       'revision_1', 'comentarios_ultimo_revisor', 'decision_editor_autor','entrada_r1', 'revision_r1',
       'comentarios_completos_r1', 'decision_editor_r1', 'entrada_r2',
       'revision_r2', 'comentarios_completos_r2', 'decision_editor_r2',
       'entrada_r3', 'revision_r3', 'comentarios_completos_r3',
       'decision_editor_r3', 'entrada_r4', 'revision_r4',
       'comentarios_completos_r4', 'rechazo', 'aceptación', 'maquetación',
       'in press', 'publicado', 'publicado_detalles', 'pmid', 'etapa_1',
       'etapa_2', 'etapa_3', 'etapa_4', 'etapa_5', 'etapa_6',
       'maquet_in_press', 'activo', 'ultima_accion', 'dias_pasados',
       'mas_de_10_dias']

editorial_manager_updated = pd.DataFrame(columns=final_columns)

# %%
#rename columns:

#'decision_editor_autor' to dec_editor_autor_r0
#'decision_editor_r1' to dec_editor_autor_r1
#'decision_editor_r2' to dec_editor_autor_r2
#'decision_editor_r3' to dec_editor_autor_r3

editorial_manager_updated.rename(columns={'decision_editor_autor':'dec_editor_autor_r0', 'decision_editor_r1':'dec_editor_autor_r1', 'decision_editor_r2':'dec_editor_autor_r2', 'decision_editor_r3':'dec_editor_autor_r3'}, inplace=True)

# %%
#change the data type to int in data_identity, est_ev_completo, est_ev_aceptado, est_ev_invitado, est_ev_rechazado, est_ev_tarde, año, pmid, etapa_1, etapa_2, etapa_3, etapa_4, etapa_5, etapa_6, maquet_in_press

int_type = ['data_identity', 'est_ev_completo', 'est_ev_aceptado', 'est_ev_invitado', 'est_ev_rechazado', 'est_ev_tarde',
 'año', 'pmid', 'etapa_1', 'etapa_2', 'etapa_3', 'etapa_4', 'etapa_5', 'etapa_6', 'maquet_in_press']

for i in int_type:
    editorial_manager_updated[i] = editorial_manager_updated[i].astype(int)

# %%
#change activo and mas_de_10_dias to boolean

editorial_manager_updated['activo'] = editorial_manager_updated['activo'].astype(bool)
editorial_manager_updated['mas_de_10_dias'] = editorial_manager_updated['mas_de_10_dias'].astype(bool)

# %%
#change the elements fo thelist to date in dd/mm/yyyy format withouth time

date_type = [ 'fecha_inicial', 'estado_actual', 'fecha_estado', 'fecha_vencimiento', 'entrada', 'revision_1',
         'comentarios_ultimo_revisor', 'decision_editor_autor', 'entrada_r1', 'revision_r1',
            'comentarios_completos_r1', 'decision_editor_r1', 'entrada_r2', 'revision_r2',
            'comentarios_completos_r2', 'decision_editor_r2', 'entrada_r3', 'revision_r3',
            'comentarios_completos_r3', 'decision_editor_r3', 'entrada_r4', 'revision_r4',
            'comentarios_completos_r4', 'rechazo', 'aceptación', 'maquetación', 'in press',
            'publicado', 'ultima_accion']

for col in date_type:
    editorial_manager_updated[col] = pd.to_datetime(editorial_manager_updated[col], format='%d/%m/%Y')

# %%
#save in a excel file the columns with the number of column and the type of data starting from 0

column_info = []
for i, col in enumerate(editorial_manager_updated.columns):
    column_info.append([i, col, str(editorial_manager_updated[col].dtype)])

column_info
# Out:
# [[0, 'data_identity', 'float64'],
#  [1, 'numero_manuscrito', 'object'],
#  [2, 'referencia', 'object'],
#  [3, 'revision', 'object'],
#  [4, 'titulo', 'object'],
#  [5, 'tipo_articulo', 'object'],
#  [6, 'autor', 'object'],
#  [7, 'email', 'object'],
#  [8, 'fecha_inicial', 'datetime64[ns]'],
#  [9, 'estado_actual', 'datetime64[ns]'],
#  [10, 'fecha_estado', 'datetime64[ns]'],
#  [11, 'fecha_vencimiento', 'datetime64[ns]'],
#  [12, 'editor', 'object'],
#  [13, 'decision_editor', 'object'],
#  [14, 'est_ev_completo', 'float64'],
#  [15, 'est_ev_aceptado', 'float64'],
#  [16, 'est_ev_invitado', 'float64'],
#  [17, 'est_ev_rechazado', 'float64'],
#  [18, 'est_ev_tarde', 'float64'],
#  [19, 'año', 'float64'],
#  [20, 'ref_maquetado', 'object'],
#  [21, 'estado', 'object'],
#  [22, 'responsable', 'object'],
#  [23, 'notas', 'object'],
#  [24, 'entrada', 'datetime64[ns]'],
#  [25, 'revision_1', 'datetime64[ns]'],
#  [26, 'comentarios_ultimo_revisor', 'datetime64[ns]'],
#  [27, 'decision_editor_autor', 'datetime64[ns]'],
#  [28, 'entrada_r1', 'datetime64[ns]'],
#  [29, 'revision_r1', 'datetime64[ns]'],
#  [30, 'comentarios_completos_r1', 'datetime64[ns]'],
#  [31, 'decision_editor_r1', 'datetime64[ns]'],
#  [32, 'entrada_r2', 'datetime64[ns]'],
#  [33, 'revision_r2', 'datetime64[ns]'],
#  [34, 'comentarios_completos_r2', 'datetime64[ns]'],
#  [35, 'decision_editor_r2', 'datetime64[ns]'],
#  [36, 'entrada_r3', 'datetime64[ns]'],
#  [37, 'revision_r3', 'datetime64[ns]'],
#  [38, 'comentarios_completos_r3', 'datetime64[ns]'],
#  [39, 'decision_editor_r3', 'datetime64[ns]'],
#  [40, 'entrada_r4', 'datetime64[ns]'],
#  [41, 'revision_r4', 'datetime64[ns]'],
#  [42, 'comentarios_completos_r4', 'datetime64[ns]'],
#  [43, 'rechazo', 'datetime64[ns]'],
#  [44, 'aceptación', 'datetime64[ns]'],
#  [45, 'maquetación', 'datetime64[ns]'],
#  [46, 'in press', 'datetime64[ns]'],
#  [47, 'publicado', 'datetime64[ns]'],
#  [48, 'publicado_detalles', 'object'],
#  [49, 'pmid', 'float64'],
#  [50, 'etapa_1', 'float64'],
#  [51, 'etapa_2', 'float64'],
#  [52, 'etapa_3', 'float64'],
#  [53, 'etapa_4', 'float64'],
#  [54, 'etapa_5', 'float64'],
#  [55, 'etapa_6', 'float64'],
#  [56, 'maquet_in_press', 'float64'],
#  [57, 'activo', 'object'],
#  [58, 'ultima_accion', 'datetime64[ns]'],
#  [59, 'dias_pasados', 'object'],
#  [60, 'mas_de_10_dias', 'object']]

# %%
#save 12/3/2020 in fecha_inicial in a new row stores in dd/mm/yyyy format formating before with strftime
fecha = '12/3/2020'
from datetime import datetime

#validate if the date is in the correct format
try:
    datetime.strptime(fecha, '%d/%m/%Y')
    print('correct format')
    #add the fecha to the new row
    editorial_manager_updated.loc[0, 'fecha_inicial'] = fecha


except ValueError:
    print('incorrect format')

editorial_manager_updated.loc[0, 'fecha_inicial']
# Out:
# correct format
# Timestamp('2020-12-03 00:00:00')

# %%
editorial_manager_updated
# Out:
#    data_identity numero_manuscrito referencia revision titulo tipo_articulo  \
# 0            NaN               NaN        NaN      NaN    NaN           NaN
#
#   autor email fecha_inicial estado_actual  ... etapa_2 etapa_3 etapa_4  \
# 0   NaN   NaN    2020-03-12           NaT  ...     NaN     NaN     NaN
#
#   etapa_5  etapa_6  maquet_in_press  activo  ultima_accion  dias_pasados  \
# 0     NaN      NaN              NaN     NaN            NaT           NaN
#
#    mas_de_10_dias
# 0             NaN
#
# [1 rows x 61 columns]

# %%
#delete the row 0
editorial_manager_updated.drop(0, inplace=True)

# %%
#get the values from the initial excel file Excel Editorial Manager.xlsx
# import the data from the excel file
df = pd.read_excel('Excel Editorial Manager.xlsx')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 978 entries, 0 to 977
# Data columns (total 44 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   AÑO                                                        978 non-null    datetime64[ns]
#  1   > 10 días                                                  85 non-null     object
#  2   REF                                                        978 non-null    object
#  3   REF MAQUETAD0                                              257 non-null    object
#  4   TITULO                                                     977 non-null    object
#  5   ESTADO                                                     978 non-null    object
#  6   Responsable                                                977 non-null    object
#  7   NOTAS                                                      123 non-null    object
#  8   ENTRADA                                                    978 non-null    datetime64[ns]
#  9   REVISIÓN                                                   232 non-null    datetime64[ns]
#  10  COMENT COMPL DEL ÚLTIMO REVISOR                            192 non-null    datetime64[ns]
#  11  DEC EDITOR PARA AUTOR                                      588 non-null    datetime64[ns]
#  12  ENTRADA R1 (para director: nuevo artículo)                 201 non-null    datetime64[ns]
#  13  REVISIÓN R1 (primera invitación para revisor: invitación)  93 non-null     datetime64[ns]
#  14  COMENT COMPL R1 (el último que llegue)                     73 non-null     datetime64[ns]
#  15  DEC EDITOR (el siguiente Para autor:)                      201 non-null    datetime64[ns]
#  16  ENTRADA R2 (el siguiente Para director: nuevo artículo)    49 non-null     datetime64[ns]
#  17  REVISIÓN R2 (el siguiente Para revisor: invitación)        21 non-null     datetime64[ns]
#  18  COMENT COMPL R2                                            19 non-null     datetime64[ns]
#  19  DEC EDITOR                                                 49 non-null     datetime64[ns]
#  20  ENTRADA R3                                                 12 non-null     datetime64[ns]
#  21  REVISIÓN R3                                                4 non-null      datetime64[ns]
#  22  COMENT COMPL R3                                            1 non-null      datetime64[ns]
#  23  DEC EDITOR2                                                13 non-null     datetime64[ns]
#  24  ENTRADA R4                                                 1 non-null      datetime64[ns]
#  25  REVISIÓN R4                                                1 non-null      datetime64[ns]
#  26  COMENT COMPL R4                                            1 non-null      datetime64[ns]
#  27  RECHAZO                                                    311 non-null    datetime64[ns]
#  28  ACEPTACIÓN                                                 211 non-null    datetime64[ns]
#  29  MAQUETACIÓN                                                155 non-null    datetime64[ns]
#  30  IN PRESS                                                   160 non-null    datetime64[ns]
#  31  PUBLICADO                                                  119 non-null    datetime64[ns]
#  32  PUBLICADO - detalles                                       150 non-null    object
#  33  PMID                                                       94 non-null     object
#  34  Etapa 1 (Entrada-Revisión)                                 233 non-null    object
#  35  Etapa 2 (rev-coment)                                       193 non-null    float64
#  36  Etapa 3 (coment-dec)                                       184 non-null    float64
#  37  Etapa 4 (dec-entrada R1)                                   201 non-null    float64
#  38  Etapa 5 (entr R1 - Rev R1)                                 94 non-null     float64
#  39  Etapa 6 (acept-maqueta)                                    127 non-null    float64
#  40  Maquet-In Press                                            100 non-null    object
#  41  Activo                                                     978 non-null    object
#  42  Última acción                                              978 non-null    datetime64[ns]
#  43  Días pasados                                               978 non-null    int64
# dtypes: datetime64[ns](26), float64(5), int64(1), object(12)
# memory usage: 336.3+ KB
# /opt/homebrew/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Conditional Formatting extension is not supported and will be removed
#   warn(msg)
# /opt/homebrew/lib/python3.10/site-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)

# %%
#import the data from df to editorial_manager_updated column by column

#first import the REF column to referencia column in editorial_manager_updated
editorial_manager_updated['referencia'] = df['REF']

# %%
#check if the values in the column are in the correct format: NEFRO-D-##-#####

import re


# create a regular expression to check if the data is like the pattern "NEFRO-D-##-#####"
pattern = re.compile("^NEFRO-D-[0-9]{2}-[0-9]{5}$")

#find the values that are not in the correct format and print them
for i in editorial_manager_updated['referencia']:
    if not pattern.match(i):
        print(i)

# %%
#extract the year from the column referencia and save it in the column año. the year is in the position 9 and 10 adding 2000
editorial_manager_updated['año'] = editorial_manager_updated['referencia'].str[8:10].astype(int) + 2000

# %%
#check that the year is correct. Print the different years
print(editorial_manager_updated['año'].unique())
# Out:
# [2022 2021 2020 2023 2019]

# %%
#copy REF MAQUETAD0 to ref_maquetado
editorial_manager_updated['ref_maquetado'] = df['REF MAQUETAD0']

# %%
#remove the initial spaces in the column ref_maquetado if there are any
editorial_manager_updated['ref_maquetado'] = editorial_manager_updated['ref_maquetado'].str.strip()

# %%
#change NEFRO-1127 to NEFRO_1127
editorial_manager_updated['ref_maquetado'] = editorial_manager_updated['ref_maquetado'].str.replace('-', '_')

# %%
# create a regular expression to check if the data is like the pattern "NEFRO_####" or "NEFRO_###"
pattern = re.compile("^NEFRO_[0-9]{3,4}$")

#find the values that are not in the correct format and print them
for i in editorial_manager_updated['ref_maquetado']:
    #if is not nan and not in the correct format print it
    if not pd.isnull(i) and not pattern.match(i):
        
        print(i)

# %%
#print referencia, año, and ref_maquetado from two rows where re_maquetado is not null
editorial_manager_updated.loc[editorial_manager_updated['ref_maquetado'].notnull(), ['referencia', 'año', 'ref_maquetado']]
# Out:
#            referencia   año ref_maquetado
# 0    NEFRO-D-22-00431  2022    NEFRO_1127
# 1    NEFRO-D-21-00400  2021     NEFRO_999
# 2    NEFRO-D-21-00364  2021     NEFRO_998
# 3    NEFRO-D-21-00425  2021     NEFRO_997
# 4    NEFRO-D-21-00404  2021     NEFRO_996
# ..                ...   ...           ...
# 252  NEFRO-D-20-00125  2020     NEFRO_952
# 253  NEFRO-D-21-00145  2021     NEFRO_950
# 254  NEFRO-D-20-00199  2020     NEFRO_775
# 317  NEFRO-D-22-00432  2022    NEFRO_1128
# 319  NEFRO-D-22-00355  2022    NEFRO_1126
#
# [257 rows x 3 columns]

# %%
#copy ESTADO to estado
editorial_manager_updated['estado'] = df['ESTADO']

# %%
#change Nefroplus to NefroPlus
editorial_manager_updated['estado'] = editorial_manager_updated['estado'].str.replace('Nefroplus', 'NefroPlus')

# %%
#print the different values in estado
print(editorial_manager_updated['estado'].unique())
# Out:
# ['6. Revisión Maquetación' '7. Publicado' 'Retirado' 'Rechazado'
#  '1. Nuevo esperando revisor o rechazar' '5. Aceptado'
#  '4.2 Grandes cambios' '2. En revisión' '3. Comentarios completos'
#  '4.1 Pequeños cambios' 'Decisión en curso' 'NefroPlus']

# %%
#copy Responsable to responsable
editorial_manager_updated['responsable'] = df['Responsable']

# %%
#remove the 0 values in responsable
#editorial_manager_updated['responsable'] = editorial_manager_updated['responsable'].str.replace('0', '')

#remove the nan values in responsable
#editorial_manager_updated['responsable'] = editorial_manager_updated['responsable'].str.replace('nan', '') 

#change elsevier to Elsevier
#editorial_manager_updated['responsable'] = editorial_manager_updated['responsable'].str.replace('elsevier', 'Elsevier')

#change MARIANO and Mariano to Mariano/Roberto
#editorial_manager_updated['responsable'] = editorial_manager_updated['responsable'].str.replace('MARIANO', 'Mariano/Roberto')
#editorial_manager_updated['responsable'] = editorial_manager_updated['responsable'].str.replace('Mariano', 'Mariano/Roberto')
editorial_manager_updated['responsable'] = editorial_manager_updated['responsable'].str.replace('Mariano/Roberto/Roberto', 'Mariano/Roberto')

# %%
#check the different values in responsable
print(editorial_manager_updated['responsable'].unique())
# Out:
# ['Elsevier' nan 'Mariano/Roberto' 'Autores' 'Revisores']

# %%
#import NOTAS to notas
editorial_manager_updated['notas'] = df['NOTAS']

# %%
#make a fucntion to validate if a value is in aaaa-mm-dd format
def validate_date(date_text):
    try:
        datetime.strptime(date_text, '%Y-%m-%d')
        return True
    except ValueError:
        return False

# %%
#check id the data from ENTRADA from df is in the correct format
#go through the rows of ENTRADA
for i in df['ENTRADA'].astype(str):
    #if is not nan and not in the correct format print it
    if not pd.isnull(i) and not validate_date(i):
        print(i)

# %%
#copy ENTRADA to entrada in dd/mm/yyyy format
editorial_manager_updated['entrada'] = df['ENTRADA'].astype(str).str[8:10] + '/' + df['ENTRADA'].astype(str).str[5:7] + '/' + df['ENTRADA'].astype(str).str[0:4]

# %%
#print 5 random rows from editorial_manager_updated['entrada']
print(editorial_manager_updated['entrada'].sample(5))
# Out:
# 591    04/05/2022
# 483    19/09/2022
# 488    09/09/2022
# 610    11/04/2022
# 486    13/09/2022
# Name: entrada, dtype: object

# %%
#check that all the values from the colums of the list in the df are in the correct format

#list of columns to check
date_columns_to_ckeck = ['REVISIÓN',
       'COMENT COMPL DEL ÚLTIMO REVISOR', 'DEC EDITOR PARA AUTOR',
       'ENTRADA R1 (para director: nuevo artículo)',
       'REVISIÓN R1 (primera invitación para revisor: invitación)',
       'COMENT COMPL R1 (el último que llegue)',
       'DEC EDITOR (el siguiente Para autor:)',
       'ENTRADA R2 (el siguiente Para director: nuevo artículo)',
       'REVISIÓN R2 (el siguiente Para revisor: invitación)',
       'COMENT COMPL R2', 'DEC EDITOR', 'ENTRADA R3', 'REVISIÓN R3',
       'COMENT COMPL R3', 'DEC EDITOR2', 'ENTRADA R4', 'REVISIÓN R4',
       'COMENT COMPL R4', 'RECHAZO', 'ACEPTACIÓN', 'MAQUETACIÓN', 'IN PRESS',
       'PUBLICADO']

#go through the columns of the list
for column in date_columns_to_ckeck:
    #go through the rows of the column
    for i in df[column]:
        #if is not NaT and not in the correct format print it
        if not pd.isnull(i):
            #validate if a value is in aaaa-mm-dd format
            #convert to string
            i = str(i)
            try:
                datetime.strptime(i, '%Y-%m-%d %H:%M:%S')
            except ValueError:
                print(column, i)

# %%
#import the columns of the list in the df to editorial_manager_updated.
#the equivalent columns in the df are:
#REVISIÓN = revision
#COMENT COMPL DEL ÚLTIMO REVISOR = comentarios_ultimo_revisor
#DEC EDITOR PARA AUTOR = dec_editor_autor_r0
#ENTRADA R1 (para director: nuevo artículo) = entrada_r1
#REVISIÓN R1 (primera invitación para revisor: invitación) = revision_r1
#COMENT COMPL R1 (el último que llegue) = comentarios_r1
#DEC EDITOR (el siguiente Para autor:) = dec_editor_autor_r1
#ENTRADA R2 (el siguiente Para director: nuevo artículo) = entrada_r2
#REVISIÓN R2 (el siguiente Para revisor: invitación) = revision_r2
#COMENT COMPL R2 = comentarios_r2
#DEC EDITOR = dec_editor_autor_r2
#ENTRADA R3 = entrada_r3
#REVISIÓN R3 = revision_r3
#COMENT COMPL R3 = comentarios_r3
#DEC EDITOR2 = dec_editor_autor_r3
#ENTRADA R4 = entrada_r4
#REVISIÓN R4 = revision_r4
#COMENT COMPL R4 = comentarios_r4
#RECHAZO = rechazo
#ACEPTACIÓN = aceptacion
#MAQUETACIÓN = maquetacion
#IN PRESS = in_press
#PUBLICADO = publicado

#create a dictionary with the equivalent columns in the df. The key is the column in the df and the value is the column in editorial_manager_updated
date_columns = {'REVISIÓN': 'revision',
         'COMENT COMPL DEL ÚLTIMO REVISOR': 'comentarios_ultimo_revisor',
            'DEC EDITOR PARA AUTOR': 'dec_editor_autor_r0',
            'ENTRADA R1 (para director: nuevo artículo)': 'entrada_r1',
            'REVISIÓN R1 (primera invitación para revisor: invitación)': 'revision_r1',
            'COMENT COMPL R1 (el último que llegue)': 'comentarios_r1',
            'DEC EDITOR (el siguiente Para autor:)': 'dec_editor_autor_r1',
            'ENTRADA R2 (el siguiente Para director: nuevo artículo)': 'entrada_r2',
            'REVISIÓN R2 (el siguiente Para revisor: invitación)': 'revision_r2',
            'COMENT COMPL R2': 'comentarios_r2',
            'DEC EDITOR': 'dec_editor_autor_r2',
            'ENTRADA R3': 'entrada_r3', 
            'REVISIÓN R3': 'revision_r3',
            'COMENT COMPL R3': 'comentarios_r3',
            'DEC EDITOR2': 'dec_editor_autor_r3',
            'ENTRADA R4': 'entrada_r4',
            'REVISIÓN R4': 'revision_r4',
            'COMENT COMPL R4': 'comentarios_r4',
            'RECHAZO': 'rechazo',
            'ACEPTACIÓN': 'aceptacion',
            'MAQUETACIÓN': 'maquetacion',
            'IN PRESS': 'in_press',
            'PUBLICADO': 'publicado'}

#go through the keys of the dictionary and copy the values from the df to editorial_manager_updated
for key in date_columns:
      editorial_manager_updated[date_columns[key]] = df[key]

# %%
#copy from PUBLICADO - detalles to publicado_detalles
editorial_manager_updated['publicado_detalles'] = df['PUBLICADO - detalles']

# %%
#in PMID column in df, if the value is web delete it
df['PMID'] = df['PMID'].replace('web', '')

#convert 34556354.  Las palabras claves no están ordenadas aún to 34556354
df['PMID'] = df['PMID'].str.replace('.  Las palabras claves no están ordenadas aún', '')
# Out:
# /var/folders/ch/63kj7hh97f1_0yrh4d1t0t8c0000gn/T/ipykernel_51671/4210325247.py:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['PMID'] = df['PMID'].str.replace('.  Las palabras claves no están ordenadas aún', '')

# %%
#if PMID is an empty string, delete it
df['PMID'] = df['PMID'].replace('', 0)
df['PMID'] = df['PMID'].replace('  ', '')

# %%
df['PMID'].fillna(0, inplace=True)

# %%
#convert PMID values to int
df['PMID'] = df['PMID'].astype(int)

# %%
#chek if pmid from df is a integer or is empty
for i in df['PMID']:
    if not pd.isnull(i):
        try:
            int(i)
        except ValueError:
            print('-',i,'-')

# %%
#convert 0 to NaN
import numpy as np
df['PMID'] = df['PMID'].replace(0, np.nan)

# %%
#copy PMID from df to editorial_manager_updated
editorial_manager_updated['pmid'] = df['PMID']

# %%
editorial_manager_updated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 978 entries, 0 to 977
# Data columns (total 69 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   data_identity               0 non-null      float64
#  1   numero_manuscrito           0 non-null      object
#  2   referencia                  978 non-null    object
#  3   revision                    232 non-null    datetime64[ns]
#  4   titulo                      0 non-null      object
#  5   tipo_articulo               0 non-null      object
#  6   autor                       0 non-null      object
#  7   email                       0 non-null      object
#  8   fecha_inicial               0 non-null      datetime64[ns]
#  9   estado_actual               0 non-null      datetime64[ns]
#  10  fecha_estado                0 non-null      datetime64[ns]
#  11  fecha_vencimiento           0 non-null      datetime64[ns]
#  12  editor                      0 non-null      object
#  13  decision_editor             0 non-null      object
#  14  est_ev_completo             0 non-null      float64
#  15  est_ev_aceptado             0 non-null      float64
#  16  est_ev_invitado             0 non-null      float64
#  17  est_ev_rechazado            0 non-null      float64
#  18  est_ev_tarde                0 non-null      float64
#  19  año                         978 non-null    int64
#  20  ref_maquetado               257 non-null    object
#  21  estado                      978 non-null    object
#  22  responsable                 932 non-null    object
#  23  notas                       123 non-null    object
#  24  entrada                     978 non-null    object
#  25  revision_1                  0 non-null      datetime64[ns]
#  26  comentarios_ultimo_revisor  192 non-null    datetime64[ns]
#  27  dec_editor_autor_r0         588 non-null    datetime64[ns]
#  28  entrada_r1                  201 non-null    datetime64[ns]
#  29  revision_r1                 93 non-null     datetime64[ns]
#  30  comentarios_completos_r1    0 non-null      datetime64[ns]
#  31  dec_editor_autor_r1         201 non-null    datetime64[ns]
#  32  entrada_r2                  49 non-null     datetime64[ns]
#  33  revision_r2                 21 non-null     datetime64[ns]
#  34  comentarios_completos_r2    0 non-null      datetime64[ns]
#  35  dec_editor_autor_r2         49 non-null     datetime64[ns]
#  36  entrada_r3                  12 non-null     datetime64[ns]
#  37  revision_r3                 4 non-null      datetime64[ns]
#  38  comentarios_completos_r3    0 non-null      datetime64[ns]
#  39  dec_editor_autor_r3         13 non-null     datetime64[ns]
#  40  entrada_r4                  1 non-null      datetime64[ns]
#  41  revision_r4                 1 non-null      datetime64[ns]
#  42  comentarios_completos_r4    0 non-null      datetime64[ns]
#  43  rechazo                     311 non-null    datetime64[ns]
#  44  aceptación                  0 non-null      datetime64[ns]
#  45  maquetación                 0 non-null      datetime64[ns]
#  46  in press                    0 non-null      datetime64[ns]
#  47  publicado                   119 non-null    datetime64[ns]
#  48  publicado_detalles          150 non-null    object
#  49  pmid                        67 non-null     float64
#  50  etapa_1                     0 non-null      float64
#  51  etapa_2                     0 non-null      float64
#  52  etapa_3                     0 non-null      float64
#  53  etapa_4                     0 non-null      float64
#  54  etapa_5                     0 non-null      float64
#  55  etapa_6                     0 non-null      float64
#  56  maquet_in_press             0 non-null      float64
#  57  activo                      0 non-null      object
#  58  ultima_accion               0 non-null      datetime64[ns]
#  59  dias_pasados                0 non-null      object
#  60  mas_de_10_dias              0 non-null      object
#  61  (0, fecha_inicial)          0 non-null      object
#  62  comentarios_r1              73 non-null     datetime64[ns]
#  63  comentarios_r2              19 non-null     datetime64[ns]
#  64  comentarios_r3              1 non-null      datetime64[ns]
#  65  comentarios_r4              1 non-null      datetime64[ns]
#  66  aceptacion                  211 non-null    datetime64[ns]
#  67  maquetacion                 155 non-null    datetime64[ns]
#  68  in_press                    160 non-null    datetime64[ns]
# dtypes: datetime64[ns](36), float64(14), int64(1), object(18)
# memory usage: 527.3+ KB

# %%
df.columns
# Out:
# Index(['AÑO', '> 10 días', 'REF', 'REF MAQUETAD0', 'TITULO', 'ESTADO',
#        'Responsable', 'NOTAS', 'ENTRADA', 'REVISIÓN',
#        'COMENT COMPL DEL ÚLTIMO REVISOR', 'DEC EDITOR PARA AUTOR',
#        'ENTRADA R1 (para director: nuevo artículo)',
#        'REVISIÓN R1 (primera invitación para revisor: invitación)',
#        'COMENT COMPL R1 (el último que llegue)',
#        'DEC EDITOR (el siguiente Para autor:)',
#        'ENTRADA R2 (el siguiente Para director: nuevo artículo)',
#        'REVISIÓN R2 (el siguiente Para revisor: invitación)',
#        'COMENT COMPL R2', 'DEC EDITOR', 'ENTRADA R3', 'REVISIÓN R3',
#        'COMENT COMPL R3', 'DEC EDITOR2', 'ENTRADA R4', 'REVISIÓN R4',
#        'COMENT COMPL R4', 'RECHAZO', 'ACEPTACIÓN', 'MAQUETACIÓN', 'IN PRESS',
#        'PUBLICADO', 'PUBLICADO - detalles', 'PMID',
#        'Etapa 1 (Entrada-Revisión)', 'Etapa 2 (rev-coment)',
#        'Etapa 3 (coment-dec)', 'Etapa 4 (dec-entrada R1)',
#        'Etapa 5 (entr R1 - Rev R1)', 'Etapa 6 (acept-maqueta)',
#        'Maquet-In Press', 'Activo', 'Última acción', 'Días pasados'],
#       dtype='object')

# %% [markdown]
# # Cálculo de los campos de la excel definitiva
# año, estado,
